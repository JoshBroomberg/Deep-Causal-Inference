# %%
import numpy as np
import rpy2
import rpy2.robjects as robjects
import pickle
from time import time

# %%
def store_results_dict(results, name):
    pickle.dump(results, open("./Results/{}.p".format(name), "wb" ))
    
def retrieve_results_dict(name):
    try:
        return pickle.load(open( "./Results/{}.p".format(name), "rb" ))
    except Exception as e:
        return None

# %% [markdown]
# ### Data Generation

# %% [markdown]
# #### Raw Data

# %%
# GLOBAL CONFIG

# Var count
n_vars = 10

# Data types (default is standard normal)
binary_indeces = [1, 3, 6, 8, 9]
binarize = True

# Associations between vars an treat/outcome
treat_vars = [0,1,2,3,4,5,6,7]
outcome_vars = [0,1,2,3,4,8,9,10]

# Treat/outcome generation weights
assignment_weights = np.array([0, 0.8, -0.25, 0.6, -0.4, -0.8, -0.5, 0.7])
outcome_weights = np.array([-3.85, 0.3, -0.36, -0.73, -0.2, 0.71, -0.19, 0.26])
true_treat_effect = -0.4

def generate_data(n_samples=1000):
    # Generate 10 Random Vars
    # 1-4 are confounders: associated with outcome + treatment
    # 5-7 are exposure predictors
    # 8-10 are outcome predictors
    X = np.random.normal(loc=0.0, scale=1.0, size=(n_samples, n_vars))

    # Binarize specified vars if requested.
    if binarize:
        for var in binary_indeces:
            X[:, var-1] = (X[:, var -1] > 0).astype(int)

    # Add dummy for bias param     
    X = np.hstack([np.ones((n_samples, 1)), X])
    return X

# %%
# DEBUG
# X = generate_data(2000)
# X.shape

# %% [markdown]
# #### Assignment

# %%
# Create the models

assignment_models={}

def nonlinear_transform(X, B, quad_indeces):
    for quad_index in quad_indeces:
        quad = X[:, quad_index]**2
        X = np.hstack([X, quad.reshape(-1, 1)])
        B = np.append(B, B[quad_index])
    
    return X, B

def nonadditive_transform(X, B, interaction_indeces, interaction_weights=None):
    for interaction_index, var_indeces in enumerate(interaction_indeces):
        int_1, int_2 = var_indeces
        interaction_val = X[:, int_1]*X[:, int_2]
        
        if not interaction_weights:
            interaction_val = interaction_val*0.5
        else:
            interaction_val = interaction_val*interaction_weights[interaction_index]
            
        X = np.hstack([X, interaction_val.reshape(-1, 1)])
        B = np.append(B, B[int_1])
    
    return X, B

# Scenario 1
assignment_models["A_add_lin"] = lambda B, X: np.dot(X, B)

# Scenario 2:     
assignment_models["B_add_mild_nlin"] = lambda B, X: np.dot(*nonlinear_transform(X, B,
                                                       quad_indeces=[2]))
# Scenario 3:
assignment_models["C_add_mod_nlin"] = lambda B, X: np.dot(*nonlinear_transform(X, B,
                                                       quad_indeces=[2, 4, 7]))
# Scenario 4:
assignment_models["D_mild_nadd_lin"] = lambda B, X: np.dot(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (4,5), (5,6)]))

# Scenario 5:
assignment_models["E_mild_nadd_mild_nlin"] = lambda B, X: np.dot(*nonlinear_transform(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (4,5), (5,6)]), quad_indeces=[2]))
# Scenario 6
assignment_models["F_mod_nadd_lin"] = lambda B, X: np.dot(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (3,5), (4,6), (5,7), (1,6), (2,3),
                                                                            (3,4), (4,5), (5,6)],
                                                       interaction_weights=[0.5, 0.7, 0.5, 0.7, 0.5, 0.5, 0.7, 0.5, 0.5, 0.5]))
# Scenario 7
assignment_models["G_mod_nadd_mod_nlin"] = lambda B, X: np.dot(*nonlinear_transform(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (3,5), (4,6), (5,7), (1,6), (2,3),
                                                                            (3,4), (4,5), (5,6)],
                                                       interaction_weights=[0.5, 0.7, 0.5, 0.7, 0.5, 0.5, 0.7, 0.5, 0.5, 0.5]), 
                                                                            quad_indeces=[2, 4, 7]))

# %%
# Tests 
assert(set(assignment_models["A_add_lin"](np.array([2, 0.5, 1.5]),
                                                np.array([[1, 2,4], [1, 10, 20]]))) == set([9, 37]))

assert(set(assignment_models["B_add_mild_nlin"](np.array([2, 0.5, 1.5]),
                                                np.array([[1, 2,4], [1, 10, 20]]))) == set([33, 637]))

assert(set(assignment_models["C_add_mod_nlin"](np.array([2, 0.5, 1.5, 1, 1, 1, 2, 3]),
                                                np.array([[1, 2,4,5,6,7,8,9], [1, 10, 20, 30, 40, 50, 60, 60]]))) == set([373, 13457]))

assert(set(assignment_models["D_mild_nadd_lin"](np.array([2, 0.5, 1.5, 1, 1, 1, 2, 3]),
                                                np.array([[1, 2,4,5,6,7,8,9], [1, 10, 20, 30, 40, 50, 60, 60]]))) == set([139.5, 3632]))

assert(set(assignment_models["E_mild_nadd_mild_nlin"](np.array([2, 0.5, 1.5, 1, 1, 1, 2, 3]),
                                                np.array([[1, 2,4,5,6,7,8,9], [1, 10, 20, 30, 40, 50, 60, 60]]))) == set([163.5, 4232]))

# %% [markdown]
# #### Outcome and Assignment Functions

# %%
def get_assignments(B, X, n_samples, scenario="A_add_lin"):
    X_usable = X[:, treat_vars]
    
    # Calculate the probabilities of assignment
    linear_assignment_data = assignment_models[scenario](B, X_usable)
    p_treat = 1.0/(1+np.exp(-1*linear_assignment_data))

    # Assign
    rand = np.random.random(n_samples)
    assignments = (rand < p_treat).astype(int)
    
    return assignments

# %%
def get_outcomes(B, X, assignments, effect=true_treat_effect):
    X_usable = X[:, outcome_vars]
    return effect*assignments + np.dot(X_usable, B)

# %%
# DEBUG
# assignments = get_assignments(assignment_weights, X, "mild_nonaddititive_mild_nonlinear")
# outcomes = get_outcomes(outcome_weights, X, assignments)

# %% [markdown]
# ### Analysis

# %%
from rpy2.robjects import IntVector, FloatVector, Formula
from rpy2.robjects.packages import importr
from rpy2.robjects import numpy2ri
numpy2ri.activate()

stats = importr('stats')
matching = importr('Matching')
snow = importr('snow')

# %% [markdown]
# Some code is going to >48 hours to ran. Lucky it's highly parellalisable so we can use a compute cluster. The one option is local to split across CPU cores. The better option is to go remote and explote 32 cores on multiple AWS machines.
#
# This simple python interface provide what we need to do that. Don't forget to port forward!. This allows the remote machine to connect to ports on the master via it's localhost loopback.
#
# ```
# # ~/.bash_profile
# # Allow remote host to connect to local machine
# # usage: $ remote_pfwd hostname {6000..6009}
# function remote_pfwd {
#   for i in ${@:2}
#   do
#     ssh -N -R $i:localhost:$i $1 &
#   done
# }
# ```
# `remote_pfwd ubuntu@52.90.20.45 {11305..11307}`

# %%
#remote_host="ubuntu@184.73.51.120"
#!remote_pfwd ubuntu@52.90.20.45 {11305..11307}

# %%
class ClusterProvider(object):
    def __init__(self, n_nodes=8, remote_hosts=None, port_range=list(range(11305, 11340))):
        if remote_hosts is None:
            self.cl = snow.makeSOCKcluster(["localhost"]*n_nodes)
        else:
            addresses = []
            for remote_host, n_nodes in remote_hosts:
                addresses+=[remote_host]*n_nodes
            self.cl = snow.makeSOCKcluster(addresses, rscript="Rscript", manual=False, snowlib="/usr/local/lib/R/site-library",
                                           port=IntVector(port_range), master="localhost", outfile="/dev/stdout", timeout=10)
    
    def get_cluster(self):
        return self.cl
    
    def kill_cluster(self):
        snow.stopCluster(self.cl)

# %%
cluster_provider = ClusterProvider(remote_hosts=[("ubuntu@54.204.196.107", 8)],
                                    port_range = list(range(11305, 11338)))
# cluster_provider = ClusterProvider(n_nodes=8)

# %%
cluster_provider.kill_cluster()

# %% [markdown]
# #### Estimators
#
# Define methods which can process outcomes, assignments and covariate data into a treatment effect estimate.
#
# 1. Logistic Regression
# 2. GenMatch
# 3. VAE

# %%
def get_propensity_scores(assignments, covariate_data):
    # Setup
    y = IntVector(assignments)
    fmla = Formula('y ~ X')
    env = fmla.environment
    
    # Run propensiy regression
    env['X'] = covariate_data
    env['y'] = y
    fit = stats.glm(fmla, family="binomial")
    
    # DEBUG: fit.rx("coefficients")
    return fit.rx2("fitted.values")

# %%
# 1. Logisic Regression Propensity Matching
def logistic_prop_matching_est(outcomes, assignments, covariate_data):
    
    propensity_scores = get_propensity_scores(assignments, covariate_data)
    
    # Run matching
    match_out = matching.Match(
        Y=FloatVector(outcomes),
        Tr=IntVector(assignments),
        X=propensity_scores,
        replace=True)
    
    return np.array(match_out.rx2("est").rx(1,1))[0]

# %%
# 2. GenMatch Matching
def genmatch_est(outcomes, assignments, covariate_data):
    
    # Get the singleton cluster
    cl = cluster_provider.get_cluster()
    
    # Add prop scores to covar data
    propensity_scores = np.array(get_propensity_scores(assignments, covariate_data))
    matching_data = np.hstack([covariate_data, propensity_scores.reshape(-1, 1)])
    
    start = time()
    gen_out = matching.GenMatch(
        Tr=IntVector(assignments),
        X=matching_data,
        BalanceMatrix=covariate_data,
        print_level=0,
        cluster=cl)
    print("GenMatch Time: ", time() - start)
    
    match_out = matching.Match(
        Y=FloatVector(outcomes),
        Tr=IntVector(assignments),
        X=covariate_data,
        replace=True,
        Weight_matrix=gen_out)
    
    return np.array(match_out.rx2("est").rx(1,1))[0]

# %%
# DEBUG
# est = logistic_prop_matching_est(assignments, X[:, 1:]) # exclude the bias term
# np.array(est)

# %%
# DEBUG
# est = genmatch_est(assignments, X[:, 1:]) # exclude the bias term
# np.array(est)

# %% [markdown]
# #### Monte Carlo Runner Code

# %%
def get_data(n_samples, assignment_model):
    X = generate_data(n_samples)
    assignments = get_assignments(assignment_weights, X,
                                  n_samples, assignment_model)

    outcomes = get_outcomes(outcome_weights, X, assignments)
    
    return assignments, outcomes, X

def get_estimate(outcomes, assignments, covar_data, method):
    return method(outcomes, assignments, covar_data)

# %%
def run_simulation(runs=1000, n_samples=1000,
                   assignment_model="additive_linear",
                   estimator=logistic_prop_matching_est,
                   verbose=True):
    
    progress_tick = max(1, int(runs/10))
    results = np.zeros(runs)

    for i in range(runs):
        assignments, outcomes, covar_data = get_data(n_samples, assignment_model)
        
        covar_data = covar_data[:, 1:] #exclude bias term
        results[i] = get_estimate(outcomes, assignments,
                                  covar_data, estimator)
        
        if i%progress_tick == progress_tick-1 and verbose:
            print("Done {} of {}".format(i+1, runs))
    
    bias = np.abs(np.mean((true_treat_effect-results)/true_treat_effect)*100)
    rmse = np.mean((true_treat_effect-results)**2)**0.5
    
    if verbose:
        print("\nRMSE", rmse)
        print("Bias", bias)
        print("===============\n\n")
    
    return {"RMSE": rmse, "Bias": bias}

# %%
# DEBUG:
run_simulation(runs=50, n_samples=1000, assignment_model="A_add_lin",
              estimator=genmatch_est, verbose=True)
# Out:
# GenMatch Time:  18.928613901138306
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.397344827651978
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  55.6703314781189
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  38.81633377075195
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.

# %% [markdown]
# ### Run MC trial

# %%
assignment_model_names = ['A_add_lin', 'B_add_mild_nlin', 'C_add_mod_nlin', 'D_mild_nadd_lin',
                     'E_mild_nadd_mild_nlin', 'F_mod_nadd_lin', 'G_mod_nadd_mod_nlin']
def run_test_battery(est,
                     store_name=None, 
                     runs=1000,
                     n_samples=1000,
                     models=assignment_models,
                     overwrite=False, verbosity=1):
    # Logging
    def printer(level, *args):
        if level <= verbosity:
            print(*args)
    
    # Storage
    if store_name is None:
        if set(models) == set(assignment_model_names):
            store_name = "est_{}_runs_{}_n_{}".format(
                est.__name__,
                runs,
                n_samples)
        else:
            store_name = "est_{}_runs_{}_n_{}_models_{}".format(
                est.__name__,
                runs,
                n_samples,
                "_".join(models))
            
    results = retrieve_results_dict(store_name)

    if overwrite or (not results):
        printer(1, "No valid, existant results found. Beggining battery.\n")
        results = {}
        for model in models:
            printer(1, "Running: ", model)
            results[model] = run_simulation(
                                runs=runs,
                                n_samples=n_samples,
                                assignment_model=model,
                                estimator=est,
                                verbose=(verbosity==2))
            store_results_dict(results[model], store_name+"_checkpoint_"+model)
            printer(1, "Done.\n")

        store_results_dict(results, store_name)
    else:
        printer(1, "Displaying cached results.\n")
    
    printer(1, "Results")
    for model, results in results.items():
        printer(1, "Model: ", model)
        print(1, "Bias: ", results["Bias"])
        print(1, "RMSE: ", results["RMSE"], "\n")

# %%
run_test_battery(
    est=logistic_prop_matching_est,
    runs=1000,
    n_samples=1000)
# Out:
# Displaying cached results.
#
# Results
# Model:  A_add_lin
# 1 Bias:  0.045874914703647685
# 1 RMSE:  0.07310500057973227
#
# Model:  B_add_mild_nlin
# 1 Bias:  3.1844355433209786
# 1 RMSE:  0.06588422028138122
#
# Model:  C_add_mod_nlin
# 1 Bias:  10.094350684204597
# 1 RMSE:  0.07650839711310455
#
# Model:  D_mild_nadd_lin
# 1 Bias:  6.720731771408928
# 1 RMSE:  0.08531717119502563
#
# Model:  E_mild_nadd_mild_nlin
# 1 Bias:  10.36168716658826
# 1 RMSE:  0.09094245826533698
#
# Model:  F_mod_nadd_lin
# 1 Bias:  3.1228082403965436
# 1 RMSE:  0.07605107262377982
#
# Model:  G_mod_nadd_mod_nlin
# 1 Bias:  11.830178367664905
# 1 RMSE:  0.07798212919046259

# %%
run_test_battery(
    est=genmatch_est,
    runs=1000,
    n_samples=1000,
    models=assignment_model_names[3:5],
    verbosity=2)
# Out:
# No valid, existant results found. Beggining battery.
#
# Running:  D_mild_nadd_lin
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required namespace: rgenoud
#
#   warnings.warn(x, RRuntimeWarning)
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required namespace: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# GenMatch Time:  17.909931659698486
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.087615489959717
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.974268436431885
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.009857654571533
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.796778678894043
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.609666347503662
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.350683450698853
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.05488920211792
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.36653995513916
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.822078943252563
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.260616779327393
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.867823362350464
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.308930158615112
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.389312982559204
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.17612934112549
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.014024257659912
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.228397607803345
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.872700452804565
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.186390399932861
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.781862497329712
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.936684370040894
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.934861421585083
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  33.69367241859436
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.157556295394897
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.522241353988647
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  33.29357671737671
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.204424142837524
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.252533674240112
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.303015232086182
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.0896155834198
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.327343940734863
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.527320623397827
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.195181846618652
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.761940956115723
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.923809051513672
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.559863805770874
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.917962312698364
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.804598569869995
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.56428050994873
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.305457830429077
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.652391910552979
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.69592571258545
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.241909742355347
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.4267098903656
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.403292894363403
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.244354248046875
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.346103429794312
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  29.01371955871582
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.699143886566162
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  21.197824954986572
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.027225255966187
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.809581518173218
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.58236074447632
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.612401962280273
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  34.56177258491516
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.621185779571533
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.9209303855896
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.616350650787354
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  6.7956202030181885
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.314296960830688
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.14839482307434
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.00960636138916
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.193912744522095
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.256184816360474
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.802080631256104
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.66090154647827
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.102226972579956
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.147400617599487
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.619849681854248
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.623077154159546
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  6.866103887557983
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.065459966659546
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.045178413391113
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.99351978302002
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.042186260223389
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.403172492980957
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.419489860534668
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.36065101623535
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.30574917793274
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.428234338760376
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.026713609695435
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  39.488884687423706
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.274413347244263
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.131117820739746
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  30.86203408241272
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.300749063491821
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  40.73991012573242
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.001465082168579
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.433165550231934
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.836989164352417
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.44252586364746
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  51.4859459400177
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.811542272567749
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.06234359741211
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.061332941055298
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.77164888381958
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.353269338607788
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.344789266586304
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  27.94295644760132
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.758838176727295
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# Done 100 of 1000
# GenMatch Time:  20.11139488220215
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.98286747932434
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.952086448669434
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.2979154586792
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.70978307723999
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.305964946746826
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.05326509475708
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.665536165237427
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  42.838332653045654
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.010234117507935
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.114441394805908
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.804007053375244
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.15652871131897
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.663785696029663
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.685389280319214
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.54789662361145
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.680456399917603
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  30.28639578819275
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.645886421203613
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.33183193206787
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.08061933517456
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.236498594284058
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  31.7027645111084
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.914798974990845
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.71176266670227
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.875996589660645
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.605313777923584
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.547367811203003
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.597468614578247
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  37.40347504615784
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  37.818100452423096
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.010465145111084
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.59022307395935
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.45469331741333
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.892385482788086
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.578784465789795
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.06043291091919
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.006836414337158
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.906991958618164
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.41874361038208
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.681579113006592
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.13810133934021
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.356117248535156
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.5356547832489
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.950219869613647
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.360930919647217
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.49742031097412
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  13.413588762283325
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  31.440165996551514
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.466376304626465
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.571070432662964
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.119603157043457
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.791703462600708
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.780858993530273
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.04556655883789
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.918437480926514
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.660009622573853
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.908539772033691
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.21657109260559
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.845691680908203
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.000293731689453
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.185763359069824
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.175485849380493
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.116461277008057
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.022129774093628
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.831084489822388
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.1505868434906
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.202053785324097
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.44055461883545
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  30.464446783065796
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  34.58725547790527
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.555106163024902
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.63961911201477
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.69586968421936
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.64821720123291
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.265743255615234
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.14974021911621
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.92730736732483
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.631572008132935
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  40.330562114715576
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.066802740097046
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.017096042633057
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.798919439315796
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.752495527267456
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.627614498138428
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.683104515075684
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.418233633041382
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.275263786315918
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.622178792953491
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.637965679168701
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.065779447555542
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.64968204498291
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.600075006484985
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.22395348548889
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.538709878921509
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  35.53467154502869
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  36.10636878013611
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.819862365722656
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.229975938796997
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.616868734359741
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# Done 200 of 1000
# GenMatch Time:  19.910081386566162
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.425872564315796
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.084838628768921
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  37.382420778274536
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.646159887313843
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.296808242797852
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.190311908721924
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.074251890182495
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.058734893798828
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.415913343429565
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.664535284042358
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.393251657485962
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  34.24765086174011
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.032814502716064
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.763753652572632
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.28427219390869
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.413178443908691
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.943451881408691
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.240199565887451
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.582082748413086
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.104249238967896
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.341403245925903
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.059029817581177
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.906642198562622
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.197335243225098
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.847663402557373
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.395204067230225
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.96455216407776
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.939726829528809
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.42591118812561
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.576338291168213
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.904839038848877
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.306031465530396
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.516737461090088
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.473403930664062
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.499405145645142
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.307199478149414
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.828270435333252
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.73932147026062
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.376972675323486
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  53.43478798866272
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.44075632095337
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.786229133605957
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.51140832901001
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.56868815422058
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  18.998438835144043
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.641672134399414
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.944103956222534
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.09900164604187
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.206384658813477
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.64606785774231
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.289883852005005
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  33.25111484527588
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.539364337921143
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.001737356185913
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.852891206741333
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.382296562194824
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.797114133834839
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.738194704055786
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.12597155570984
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.946563482284546
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.186434268951416
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.777737379074097
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.325363636016846
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.660617113113403
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.040685653686523
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.689887762069702
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.420471906661987
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.635836362838745
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.565461158752441
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.03597331047058
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.57831835746765
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.64534282684326
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.742727518081665
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.583736181259155
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.522984504699707
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.106523513793945
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.321943044662476
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.96731662750244
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.225796222686768
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# ...
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.529205322265625
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# Done 400 of 1000
# GenMatch Time:  13.216865301132202
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.775676488876343
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.757936477661133
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.35220003128052
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.702101707458496
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.047685146331787
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.262474536895752
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.545364141464233
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.93048334121704
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.674201011657715
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.680866479873657
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.777079820632935
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.07109570503235
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.315990209579468
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  29.831464052200317
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.408069849014282
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.060492038726807
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.748100996017456
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.344555854797363
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.29246950149536
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.396411657333374
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.965174198150635
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.28344702720642
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.196648359298706
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.398861408233643
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  37.91884160041809
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.317615270614624
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.771470546722412
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.130815029144287
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.27941608428955
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.70340633392334
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.98713779449463
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.70887804031372
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.937947988510132
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.018917083740234
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.178982734680176
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.734485626220703
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.078558683395386
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.465119361877441
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.03397822380066
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.201631546020508
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  16.33001160621643
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.833427667617798
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.70485305786133
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.24163818359375
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.71773338317871
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.004523754119873
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.320502996444702
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.709808826446533
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.19449210166931
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.5397469997406
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.808987379074097
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.211966037750244
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.93163299560547
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.324922800064087
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.39349055290222
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.879267930984497
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.214050531387329
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.653655290603638
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.292802810668945
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.766817331314087
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.624407529830933
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.418211460113525
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.827648401260376
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.915853261947632
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.67805790901184
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.972407102584839
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.74837303161621
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.035989999771118
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.303840160369873
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.100259065628052
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.740456104278564
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.023236751556396
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.763286828994751
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.570611715316772
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.758792161941528
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.48923110961914
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: There were 50 or more warnings (use warnings() to see the first 50)
#   warnings.warn(x, RRuntimeWarning)
# ---------------------------------------------------------------------------
# RRuntimeError                             Traceback (most recent call last)
# <ipython-input-22-3e0781271ea8> in <module>()
#       4     n_samples=1000,
#       5     models=assignment_model_names[3:5],
# ----> 6     verbosity=2)
#
# <ipython-input-20-42375cfa5026> in run_test_battery(est, store_name, runs, n_samples, models, overwrite, verbosity)
#      38                                 assignment_model=model,
#      39                                 estimator=est,
# ---> 40                                 verbose=(verbosity==2))
#      41             store_results_dict(results[model], store_name+"_checkpoint_"+model)
#      42             printer(1, "Done.\n")
#
# <ipython-input-19-d9a381310f99> in run_simulation(runs, n_samples, assignment_model, estimator, verbose)
#      12         covar_data = covar_data[:, 1:] #exclude bias term
#      13         results[i] = get_estimate(outcomes, assignments,
# ---> 14                                   covar_data, estimator)
#      15
#      16         if i%progress_tick == progress_tick-1 and verbose:
#
# <ipython-input-18-4302c7a61202> in get_estimate(outcomes, assignments, covar_data, method)
#       9
#      10 def get_estimate(outcomes, assignments, covar_data, method):
# ---> 11     return method(outcomes, assignments, covar_data)
#
# <ipython-input-15-1a7ec1f7b8e9> in genmatch_est(outcomes, assignments, covariate_data)
#      15         BalanceMatrix=covariate_data,
#      16         print_level=0,
# ---> 17         cluster=cl)
#      18     print("GenMatch Time: ", time() - start)
#      19
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     104         for k, v in kwargs.items():
#     105             new_kwargs[k] = conversion.py2ri(v)
# --> 106         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     107         res = conversion.ri2ro(res)
#     108         return res
#
# RRuntimeError:

# %% [markdown]
# GenMatch bias on 1000/1000 = 4.26790791538966
