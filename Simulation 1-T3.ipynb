# %%
import numpy as np
import rpy2
import rpy2.robjects as robjects
import pickle
from time import time

# %%
def store_results_dict(results, name):
    pickle.dump(results, open("./Results/{}.p".format(name), "wb" ))
    
def retrieve_results_dict(name):
    try:
        return pickle.load(open( "./Results/{}.p".format(name), "rb" ))
    except Exception as e:
        return None

# %% [markdown]
# ### Data Generation

# %% [markdown]
# #### Raw Data

# %%
# GLOBAL CONFIG

# Var count
n_vars = 10

# Data types (default is standard normal)
binary_indeces = [1, 3, 6, 8, 9]
binarize = True

# Associations between vars an treat/outcome
treat_vars = [0,1,2,3,4,5,6,7]
outcome_vars = [0,1,2,3,4,8,9,10]

# Treat/outcome generation weights
assignment_weights = np.array([0, 0.8, -0.25, 0.6, -0.4, -0.8, -0.5, 0.7])
outcome_weights = np.array([-3.85, 0.3, -0.36, -0.73, -0.2, 0.71, -0.19, 0.26])
true_treat_effect = -0.4

def generate_data(n_samples=1000):
    # Generate 10 Random Vars
    # 1-4 are confounders: associated with outcome + treatment
    # 5-7 are exposure predictors
    # 8-10 are outcome predictors
    X = np.random.normal(loc=0.0, scale=1.0, size=(n_samples, n_vars))

    # Binarize specified vars if requested.
    if binarize:
        for var in binary_indeces:
            X[:, var-1] = (X[:, var -1] > 0).astype(int)

    # Add dummy for bias param     
    X = np.hstack([np.ones((n_samples, 1)), X])
    return X

# %%
# DEBUG
# X = generate_data(2000)
# X.shape

# %% [markdown]
# #### Assignment

# %%
# Create the models

assignment_models={}

def nonlinear_transform(X, B, quad_indeces):
    for quad_index in quad_indeces:
        quad = X[:, quad_index]**2
        X = np.hstack([X, quad.reshape(-1, 1)])
        B = np.append(B, B[quad_index])
    
    return X, B

def nonadditive_transform(X, B, interaction_indeces, interaction_weights=None):
    for interaction_index, var_indeces in enumerate(interaction_indeces):
        int_1, int_2 = var_indeces
        interaction_val = X[:, int_1]*X[:, int_2]
        
        if not interaction_weights:
            interaction_val = interaction_val*0.5
        else:
            interaction_val = interaction_val*interaction_weights[interaction_index]
            
        X = np.hstack([X, interaction_val.reshape(-1, 1)])
        B = np.append(B, B[int_1])
    
    return X, B

# Scenario 1
assignment_models["A_add_lin"] = lambda B, X: np.dot(X, B)

# Scenario 2:     
assignment_models["B_add_mild_nlin"] = lambda B, X: np.dot(*nonlinear_transform(X, B,
                                                       quad_indeces=[2]))
# Scenario 3:
assignment_models["C_add_mod_nlin"] = lambda B, X: np.dot(*nonlinear_transform(X, B,
                                                       quad_indeces=[2, 4, 7]))
# Scenario 4:
assignment_models["D_mild_nadd_lin"] = lambda B, X: np.dot(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (4,5), (5,6)]))

# Scenario 5:
assignment_models["E_mild_nadd_mild_nlin"] = lambda B, X: np.dot(*nonlinear_transform(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (4,5), (5,6)]), quad_indeces=[2]))
# Scenario 6
assignment_models["F_mod_nadd_lin"] = lambda B, X: np.dot(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (3,5), (4,6), (5,7), (1,6), (2,3),
                                                                            (3,4), (4,5), (5,6)],
                                                       interaction_weights=[0.5, 0.7, 0.5, 0.7, 0.5, 0.5, 0.7, 0.5, 0.5, 0.5]))
# Scenario 7
assignment_models["G_mod_nadd_mod_nlin"] = lambda B, X: np.dot(*nonlinear_transform(*nonadditive_transform(X, B,
                                                       interaction_indeces=[(1,3), (2, 4), (3,5), (4,6), (5,7), (1,6), (2,3),
                                                                            (3,4), (4,5), (5,6)],
                                                       interaction_weights=[0.5, 0.7, 0.5, 0.7, 0.5, 0.5, 0.7, 0.5, 0.5, 0.5]), 
                                                                            quad_indeces=[2, 4, 7]))

# %%
# Tests 
assert(set(assignment_models["A_add_lin"](np.array([2, 0.5, 1.5]),
                                                np.array([[1, 2,4], [1, 10, 20]]))) == set([9, 37]))

assert(set(assignment_models["B_add_mild_nlin"](np.array([2, 0.5, 1.5]),
                                                np.array([[1, 2,4], [1, 10, 20]]))) == set([33, 637]))

assert(set(assignment_models["C_add_mod_nlin"](np.array([2, 0.5, 1.5, 1, 1, 1, 2, 3]),
                                                np.array([[1, 2,4,5,6,7,8,9], [1, 10, 20, 30, 40, 50, 60, 60]]))) == set([373, 13457]))

assert(set(assignment_models["D_mild_nadd_lin"](np.array([2, 0.5, 1.5, 1, 1, 1, 2, 3]),
                                                np.array([[1, 2,4,5,6,7,8,9], [1, 10, 20, 30, 40, 50, 60, 60]]))) == set([139.5, 3632]))

assert(set(assignment_models["E_mild_nadd_mild_nlin"](np.array([2, 0.5, 1.5, 1, 1, 1, 2, 3]),
                                                np.array([[1, 2,4,5,6,7,8,9], [1, 10, 20, 30, 40, 50, 60, 60]]))) == set([163.5, 4232]))

# %% [markdown]
# #### Outcome and Assignment Functions

# %%
def get_assignments(B, X, n_samples, scenario="A_add_lin"):
    X_usable = X[:, treat_vars]
    
    # Calculate the probabilities of assignment
    linear_assignment_data = assignment_models[scenario](B, X_usable)
    p_treat = 1.0/(1+np.exp(-1*linear_assignment_data))

    # Assign
    rand = np.random.random(n_samples)
    assignments = (rand < p_treat).astype(int)
    
    return assignments

# %%
def get_outcomes(B, X, assignments, effect=true_treat_effect):
    X_usable = X[:, outcome_vars]
    return effect*assignments + np.dot(X_usable, B)

# %%
# DEBUG
# assignments = get_assignments(assignment_weights, X, "mild_nonaddititive_mild_nonlinear")
# outcomes = get_outcomes(outcome_weights, X, assignments)

# %% [markdown]
# ### Analysis

# %%
from rpy2.robjects import IntVector, FloatVector, Formula
from rpy2.robjects.packages import importr
from rpy2.robjects import numpy2ri
numpy2ri.activate()

stats = importr('stats')
matching = importr('Matching')
snow = importr('snow')

# %% [markdown]
# Some code is going to >48 hours to ran. Lucky it's highly parellalisable so we can use a compute cluster. The one option is local to split across CPU cores. The better option is to go remote and explote 32 cores on multiple AWS machines.
#
# This simple python interface provide what we need to do that. Don't forget to port forward!. This allows the remote machine to connect to ports on the master via it's localhost loopback.
#
# ```
# # ~/.bash_profile
# # Allow remote host to connect to local machine
# # usage: $ remote_pfwd hostname {6000..6009}
# function remote_pfwd {
#   for i in ${@:2}
#   do
#     ssh -N -R $i:localhost:$i $1 &
#   done
# }
# ```
# `remote_pfwd ubuntu@52.90.20.45 {11305..11307}`

# %%
#remote_host="ubuntu@184.73.51.120"
#!remote_pfwd ubuntu@52.90.20.45 {11305..11307}

# %%
class ClusterProvider(object):
    def __init__(self, n_nodes=8, remote_hosts=None, port_range=list(range(11305, 11340))):
        if remote_hosts is None:
            self.cl = snow.makeSOCKcluster(["localhost"]*n_nodes)
        else:
            addresses = []
            for remote_host, n_nodes in remote_hosts:
                addresses+=[remote_host]*n_nodes
            self.cl = snow.makeSOCKcluster(addresses, rscript="Rscript", manual=False, snowlib="/usr/local/lib/R/site-library",
                                           port=IntVector(port_range), master="localhost", outfile="/dev/stdout", timeout=10)
    
    def get_cluster(self):
        return self.cl
    
    def kill_cluster(self):
        snow.stopCluster(self.cl)

# %%
cluster_provider = ClusterProvider(remote_hosts=[("ubuntu@52.70.238.90", 8)],
                                    port_range = list(range(11315, 11338)))
# cluster_provider = ClusterProvider(n_nodes=8)

# %%
cluster_provider.kill_cluster()

# %% [markdown]
# #### Estimators
#
# Define methods which can process outcomes, assignments and covariate data into a treatment effect estimate.
#
# 1. Logistic Regression
# 2. GenMatch
# 3. VAE

# %%
def get_propensity_scores(assignments, covariate_data):
    # Setup
    y = IntVector(assignments)
    fmla = Formula('y ~ X')
    env = fmla.environment
    
    # Run propensiy regression
    env['X'] = covariate_data
    env['y'] = y
    fit = stats.glm(fmla, family="binomial")
    
    # DEBUG: fit.rx("coefficients")
    return fit.rx2("fitted.values")

# %%
# 1. Logisic Regression Propensity Matching
def logistic_prop_matching_est(outcomes, assignments, covariate_data):
    
    propensity_scores = get_propensity_scores(assignments, covariate_data)
    
    # Run matching
    match_out = matching.Match(
        Y=FloatVector(outcomes),
        Tr=IntVector(assignments),
        X=propensity_scores,
        replace=True)
    
    return np.array(match_out.rx2("est").rx(1,1))[0]

# %%
# 2. GenMatch Matching
def genmatch_est(outcomes, assignments, covariate_data):
    
    # Get the singleton cluster
    cl = cluster_provider.get_cluster()
    
    # Add prop scores to covar data
    propensity_scores = np.array(get_propensity_scores(assignments, covariate_data))
    matching_data = np.hstack([covariate_data, propensity_scores.reshape(-1, 1)])
    
    start = time()
    gen_out = matching.GenMatch(
        Tr=IntVector(assignments),
        X=matching_data,
        BalanceMatrix=covariate_data,
        print_level=0,
        cluster=cl)
    print("GenMatch Time: ", time() - start)
    
    match_out = matching.Match(
        Y=FloatVector(outcomes),
        Tr=IntVector(assignments),
        X=covariate_data,
        replace=True,
        Weight_matrix=gen_out)
    
    return np.array(match_out.rx2("est").rx(1,1))[0]

# %%
# DEBUG
# est = logistic_prop_matching_est(assignments, X[:, 1:]) # exclude the bias term
# np.array(est)

# %%
# DEBUG
# est = genmatch_est(assignments, X[:, 1:]) # exclude the bias term
# np.array(est)

# %% [markdown]
# #### Monte Carlo Runner Code

# %%
def get_data(n_samples, assignment_model):
    X = generate_data(n_samples)
    assignments = get_assignments(assignment_weights, X,
                                  n_samples, assignment_model)

    outcomes = get_outcomes(outcome_weights, X, assignments)
    
    return assignments, outcomes, X

def get_estimate(outcomes, assignments, covar_data, method):
    return method(outcomes, assignments, covar_data)

# %%
def run_simulation(runs=1000, n_samples=1000,
                   assignment_model="additive_linear",
                   estimator=logistic_prop_matching_est,
                   verbose=True):
    
    progress_tick = max(1, int(runs/10))
    results = np.zeros(runs)

    for i in range(runs):
        assignments, outcomes, covar_data = get_data(n_samples, assignment_model)
        
        covar_data = covar_data[:, 1:] #exclude bias term
        results[i] = get_estimate(outcomes, assignments,
                                  covar_data, estimator)
        
        if i%progress_tick == progress_tick-1 and verbose:
            print("Done {} of {}".format(i+1, runs))
    
    bias = np.abs(np.mean((true_treat_effect-results)/true_treat_effect)*100)
    rmse = np.mean((true_treat_effect-results)**2)**0.5
    
    if verbose:
        print("\nRMSE", rmse)
        print("Bias", bias)
        print("===============\n\n")
    
    return {"RMSE": rmse, "Bias": bias}

# %%
# DEBUG:
run_simulation(runs=50, n_samples=1000, assignment_model="A_add_lin",
              estimator=genmatch_est, verbose=True)
# Out:
# GenMatch Time:  18.928613901138306
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.397344827651978
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  55.6703314781189
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  38.81633377075195
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.

# %% [markdown]
# ### Run MC trial

# %%
assignment_model_names = ['A_add_lin', 'B_add_mild_nlin', 'C_add_mod_nlin', 'D_mild_nadd_lin',
                     'E_mild_nadd_mild_nlin', 'F_mod_nadd_lin', 'G_mod_nadd_mod_nlin']
def run_test_battery(est,
                     store_name=None, 
                     runs=1000,
                     n_samples=1000,
                     models=assignment_models,
                     overwrite=False, verbosity=1):
    # Logging
    def printer(level, *args):
        if level <= verbosity:
            print(*args)
    
    # Storage
    if store_name is None:
        if set(models) == set(assignment_model_names):
            store_name = "est_{}_runs_{}_n_{}".format(
                est.__name__,
                runs,
                n_samples)
        else:
            store_name = "est_{}_runs_{}_n_{}_models_{}".format(
                est.__name__,
                runs,
                n_samples,
                "_".join(models))
            
    results = retrieve_results_dict(store_name)

    if overwrite or (not results):
        printer(1, "No valid, existant results found. Beggining battery.\n")
        results = {}
        for model in models:
            printer(1, "Running: ", model)
            results[model] = run_simulation(
                                runs=runs,
                                n_samples=n_samples,
                                assignment_model=model,
                                estimator=est,
                                verbose=(verbosity==2))
            store_results_dict(results[model], store_name+"_checkpoint_"+model)
            printer(1, "Done.\n")

        store_results_dict(results, store_name)
    else:
        printer(1, "Displaying cached results.\n")
    
    printer(1, "Results")
    for model, results in results.items():
        printer(1, "Model: ", model)
        print(1, "Bias: ", results["Bias"])
        print(1, "RMSE: ", results["RMSE"], "\n")

# %%
run_test_battery(
    est=logistic_prop_matching_est,
    runs=1000,
    n_samples=1000)
# Out:
# Displaying cached results.
#
# Results
# Model:  A_add_lin
# 1 Bias:  0.045874914703647685
# 1 RMSE:  0.07310500057973227
#
# Model:  B_add_mild_nlin
# 1 Bias:  3.1844355433209786
# 1 RMSE:  0.06588422028138122
#
# Model:  C_add_mod_nlin
# 1 Bias:  10.094350684204597
# 1 RMSE:  0.07650839711310455
#
# Model:  D_mild_nadd_lin
# 1 Bias:  6.720731771408928
# 1 RMSE:  0.08531717119502563
#
# Model:  E_mild_nadd_mild_nlin
# 1 Bias:  10.36168716658826
# 1 RMSE:  0.09094245826533698
#
# Model:  F_mod_nadd_lin
# 1 Bias:  3.1228082403965436
# 1 RMSE:  0.07605107262377982
#
# Model:  G_mod_nadd_mod_nlin
# 1 Bias:  11.830178367664905
# 1 RMSE:  0.07798212919046259

# %%
run_test_battery(
    est=genmatch_est,
    runs=1000,
    n_samples=1000,
    models=assignment_model_names[5:],
    verbosity=2)
# Out:
# No valid, existant results found. Beggining battery.
#
# Running:  F_mod_nadd_lin
# GenMatch Time:  29.060919046401978
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required namespace: rgenoud
#
#   warnings.warn(x, RRuntimeWarning)
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Loading required namespace: parallel
#
#   warnings.warn(x, RRuntimeWarning)
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.018697023391724
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.895472764968872
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.14227032661438
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.635174989700317
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.49373459815979
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.563663959503174
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.907811164855957
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  30.659515142440796
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.703994750976562
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  6.49481987953186
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.330725193023682
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.678723573684692
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.74205732345581
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.0119411945343
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.734152793884277
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.152952671051025
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.683712482452393
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.96796989440918
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.493189811706543
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.431008100509644
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.852141857147217
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.149651527404785
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.463043451309204
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.149488925933838
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.426981687545776
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.519975900650024
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.552420854568481
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.22114872932434
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.002617835998535
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.815107583999634
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.720730781555176
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.658480167388916
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.741387605667114
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.762423753738403
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.319234371185303
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.806945562362671
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.892855167388916
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.406155109405518
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.82629895210266
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.321316957473755
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.014979600906372
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.712056159973145
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.804543256759644
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.516602277755737
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.777435302734375
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.303014993667603
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.396563291549683
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.678187847137451
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  14.296522617340088
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  29.773343801498413
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.631804943084717
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.742955446243286
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.478609085083008
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.46165943145752
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.522691249847412
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.019898176193237
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.02973508834839
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.189785242080688
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.53698992729187
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.267587184906006
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.563584804534912
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.845715284347534
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.250602006912231
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.376562118530273
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.554199457168579
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.094650506973267
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.599624156951904
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.00194025039673
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.268332958221436
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.35308027267456
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.3629310131073
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  40.59807252883911
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.21969985961914
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.061537742614746
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.229470252990723
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.90686845779419
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.828923225402832
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.174954652786255
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.8043794631958
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.579372882843018
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.048958778381348
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.627488374710083
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.775431394577026
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.534140586853027
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.54109525680542
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.171561002731323
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.01825261116028
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.93528938293457
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.60152244567871
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.937932968139648
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.425229549407959
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.110401153564453
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.54450273513794
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.334306955337524
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.964587926864624
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.21418309211731
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.427407026290894
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  15.25717544555664
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.887451171875
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# Done 100 of 1000
# GenMatch Time:  17.77647590637207
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.119889974594116
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.823105096817017
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.061164140701294
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.317429542541504
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.98186206817627
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.337587356567383
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.390432119369507
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.228449583053589
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.56827473640442
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.282306432724
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.024397134780884
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.013309717178345
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.573583841323853
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.0471062660217285
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.68896722793579
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.52337074279785
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.02439022064209
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.582449197769165
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.621244430541992
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.918960094451904
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.089006662368774
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.27517604827881
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.518228769302368
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  33.97146248817444
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.52075695991516
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.114940643310547
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.76690149307251
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.051562309265137
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.304582357406616
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.9679434299469
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.071716785430908
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.117318153381348
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.912712097167969
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.911983728408813
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.113184213638306
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.4679057598114
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.418840408325195
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.61333656311035
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.561750411987305
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.940523862838745
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.500188112258911
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.825103282928467
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.022519826889038
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.120993375778198
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.092336416244507
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.77502727508545
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  13.495060443878174
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.158815383911133
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.914156675338745
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.410582542419434
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.080181360244751
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.239516496658325
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  31.11231803894043
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.284461736679077
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.029247522354126
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.993109703063965
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.699281930923462
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.612776517868042
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.96612858772278
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.39335823059082
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.016693115234375
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.065753698348999
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.339908123016357
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.533947229385376
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.952574253082275
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.04656219482422
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  34.97099328041077
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.196337461471558
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.585092782974243
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.39891266822815
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.150683403015137
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.399067640304565
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.607162475585938
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.34415316581726
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.139349937438965
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.644667387008667
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.153300523757935
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.56066107749939
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.026055812835693
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.43903422355652
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  30.27118229866028
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.508188486099243
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.47005271911621
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.685977935791016
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.116351842880249
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.792136669158936
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.238081693649292
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  29.394797325134277
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.76929497718811
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.690829038619995
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.642901182174683
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  27.706511974334717
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.18167805671692
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.826842784881592
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.972632646560669
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  31.32244849205017
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.103790521621704
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.85119891166687
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.961127042770386
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# Done 200 of 1000
# GenMatch Time:  13.349695682525635
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.97471022605896
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.3639919757843
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  29.890926599502563
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.745134830474854
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.4402756690979
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.093799352645874
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.644196271896362
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.092578172683716
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.598973512649536
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  31.563161611557007
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.524439334869385
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.523966073989868
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  43.41659593582153
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.46098804473877
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.434010028839111
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.52237033843994
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.616438627243042
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.909184455871582
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.927083730697632
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  23.000123977661133
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.250851392745972
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.484647274017334
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.601515293121338
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.17586398124695
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.548822164535522
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.59545111656189
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.307749032974243
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.055240154266357
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  40.371692419052124
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.338558435440063
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.079465389251709
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.24812150001526
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.381977319717407
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.097290992736816
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.031070947647095
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.409193515777588
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.351423740386963
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.39500403404236
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.76849937438965
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.194815397262573
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.838454961776733
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.478062629699707
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.273670434951782
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  31.09654402732849
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  28.5236177444458
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.253331899642944
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.57063627243042
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.305214405059814
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.265282154083252
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.760579586029053
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.790538787841797
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  26.930980920791626
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.739935636520386
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.247880220413208
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.184693336486816
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.657331705093384
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  32.55946183204651
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.002257585525513
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.764768362045288
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.882423639297485
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.647615194320679
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.611746549606323
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.343152284622192
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  8.438024282455444
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.538367748260498
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  30.924463748931885
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.886543273925781
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.016645193099976
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.593714952468872
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.515500783920288
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.88473629951477
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.455596923828125
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.729782819747925
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.09847092628479
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.2890522480011
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.315997838974
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  35.20407319068909
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.866584539413452
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.690475702285767
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# ...
#
# GenMatch Time:  12.368086099624634
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.096271276473999
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.545702934265137
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.433895111083984
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.31155037879944
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# Done 400 of 1000
# GenMatch Time:  11.657553911209106
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.320307970046997
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.149415016174316
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.984750509262085
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.558085203170776
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.187619924545288
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.77970552444458
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.899917125701904
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.428879737854004
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.372379302978516
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.480520486831665
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.72411561012268
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.852269887924194
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  43.01287770271301
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  22.684175968170166
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.60941743850708
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.746878147125244
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  37.15567398071289
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.25441884994507
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.422801494598389
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.561464548110962
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.08431625366211
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.19026231765747
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.839761734008789
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.11806583404541
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  25.320923328399658
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.292823791503906
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.037476539611816
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.036481380462646
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.858654975891113
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.206212997436523
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.473655939102173
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.12937045097351
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.48991346359253
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  16.74154496192932
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  12.302006721496582
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.543824434280396
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.886440992355347
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.950061798095703
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.16941547393799
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.783711194992065
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# GenMatch Time:  16.388460397720337
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.74027729034424
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  14.437552213668823
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  19.704221487045288
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.5930495262146
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.960267066955566
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  31.32230305671692
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.26405692100525
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.791698694229126
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.170698165893555
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.580129623413086
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.68767547607422
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.743666887283325
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.101248502731323
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  15.60531735420227
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  7.595886707305908
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  18.778594255447388
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  28.189650774002075
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.228983402252197
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.411938190460205
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  24.985881090164185
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  20.827630043029785
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  10.021860122680664
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  29.558135986328125
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  21.420390367507935
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.9345383644104
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  13.898344278335571
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  17.355156898498535
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  11.684869050979614
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
#
# GenMatch Time:  9.665166854858398
# Increasing memory because of ties: allocating a matrix of size 3 times 200000 doubles.
#
# I would be faster with the ties=FALSE option.
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: Error in serialize(data, node$con) : Interrupted
#
#   warnings.warn(x, RRuntimeWarning)
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: In addition:
#   warnings.warn(x, RRuntimeWarning)
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning: There were 50 or more warnings (use warnings() to see the first 50)
#   warnings.warn(x, RRuntimeWarning)
# /home/ubuntu/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:145: RRuntimeWarning:
#
#   warnings.warn(x, RRuntimeWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-ff87d4f396bb> in <module>()
#       4     n_samples=1000,
#       5     models=assignment_model_names[5:],
# ----> 6     verbosity=2)
#
# <ipython-input-22-42375cfa5026> in run_test_battery(est, store_name, runs, n_samples, models, overwrite, verbosity)
#      38                                 assignment_model=model,
#      39                                 estimator=est,
# ---> 40                                 verbose=(verbosity==2))
#      41             store_results_dict(results[model], store_name+"_checkpoint_"+model)
#      42             printer(1, "Done.\n")
#
# <ipython-input-21-d9a381310f99> in run_simulation(runs, n_samples, assignment_model, estimator, verbose)
#      12         covar_data = covar_data[:, 1:] #exclude bias term
#      13         results[i] = get_estimate(outcomes, assignments,
# ---> 14                                   covar_data, estimator)
#      15
#      16         if i%progress_tick == progress_tick-1 and verbose:
#
# <ipython-input-20-4302c7a61202> in get_estimate(outcomes, assignments, covar_data, method)
#       9
#      10 def get_estimate(outcomes, assignments, covar_data, method):
# ---> 11     return method(outcomes, assignments, covar_data)
#
# <ipython-input-17-1a7ec1f7b8e9> in genmatch_est(outcomes, assignments, covariate_data)
#      15         BalanceMatrix=covariate_data,
#      16         print_level=0,
# ---> 17         cluster=cl)
#      18     print("GenMatch Time: ", time() - start)
#      19
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     176                 v = kwargs.pop(k)
#     177                 kwargs[r_k] = v
# --> 178         return super(SignatureTranslatedFunction, self).__call__(*args, **kwargs)
#     179
#     180 pattern_link = re.compile(r'\\link\{(.+?)\}')
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/rpy2/robjects/functions.py in __call__(self, *args, **kwargs)
#     104         for k, v in kwargs.items():
#     105             new_kwargs[k] = conversion.py2ri(v)
# --> 106         res = super(Function, self).__call__(*new_args, **new_kwargs)
#     107         res = conversion.ri2ro(res)
#     108         return res
#
# KeyboardInterrupt:

# %% [markdown]
# GenMatch bias on 1000/1000 = 4.26790791538966
